# %% [markdown]
# # 💻 Laptop Price Prediction
#
# ## 📌 Project Overview
#
# This project focuses on cleaning, preprocessing, and analyzing an uncleaned laptop dataset and developing a machine learning regression model to predict laptop prices based on their specifications.
#
# The dataset contains more than 1,300 laptop product listings with information about brands, laptop types, screen specifications, processors, RAM, storage, GPUs, operating systems, weight, and price.
#
# The main challenge of this project is that the original dataset contains various data quality issues, including missing values, inconsistent formats, mixed data types, and unstructured information. Therefore, a significant part of the project focuses on **data cleaning and feature engineering** before applying machine learning techniques.
#
# The project follows a typical end-to-end data science workflow:
#
# **Data Cleaning → Exploratory Data Analysis → Feature Engineering → Data Preprocessing → Model Training → Model Evaluation**
#
# ---
#
# ## 🎯 Project Objective
#
# The main objective is to build a machine learning model that can estimate the price of a laptop based on its technical specifications.
#
# More specifically, the project aims to:
#
# - Clean and preprocess the raw dataset
# - Identify and handle missing and inconsistent values
# - Convert unstructured information into useful numerical features
# - Explore relationships between laptop specifications and price
# - Perform feature engineering
# - Encode categorical variables
# - Scale numerical features where appropriate
# - Train regression models
# - Evaluate model performance using appropriate regression metrics
# - Identify the most important factors affecting laptop prices
#
# ---
#
# ## 📊 Dataset Summary
#
# The dataset contains **1,300+ laptop product listings** and provides information about different laptop models and their technical specifications.
#
# The dataset contains both **categorical** and **numerical** variables.
#
# ### Categorical Features
#
# Examples include:
#
# - Brand
# - Laptop Type
# - Screen Resolution
# - CPU
# - Storage Type
# - GPU
# - Operating System
#
# ### Numerical Features
#
# Examples include:
#
# - Screen Size
# - RAM
# - Storage Capacity
# - Weight
# - Price
#
# The target variable is:
#
# > **Price** — a continuous numerical variable representing the price of the laptop.
#
# ---
#
# ## 🧹 Data Quality Challenges
#
# The original dataset is intentionally uncleaned and contains several data quality issues that need to be addressed before modeling.
#
# These include:
#
# - Missing values
# - Inconsistent formatting
# - Mixed data types
# - Numerical values stored as strings
# - Units included inside numerical columns
# - Multiple pieces of information stored in a single column
# - Inconsistent categorical values
# - Potential outliers
#
# For example, specifications such as CPU, storage, and screen resolution contain multiple pieces of information in a single text field.
#
# Therefore, the preprocessing stage is an important part of this project.
#
# ---
#
# ## 🔧 Feature Engineering
#
# One of the main goals of this project is to transform the raw laptop specifications into meaningful machine learning features.
#
# Examples of potential feature engineering include:
#
# - Extracting CPU brand and processor family
# - Extracting CPU speed
# - Converting RAM into numerical values
# - Extracting storage capacity
# - Separating SSD and HDD storage
# - Extracting screen width and height from resolution
# - Calculating total pixels
# - Creating screen aspect ratio
# - Extracting GPU brand
# - Converting laptop weight to numerical values
# - Encoding operating systems
# - Encoding laptop brands and types
#
# These transformations allow the machine learning model to work with structured numerical and categorical information rather than raw text.
#
# ---
#
# ## 📋 Column Descriptions
#
# | Column | Description |
# |---|---|
# | **Brand** | The manufacturer of the laptop, such as Apple, HP, Acer, Dell, Asus, Lenovo, or Chuwi. |
# | **Type** | The type of laptop, such as Ultrabook, Notebook, Gaming, or 2-in-1 Convertible. |
# | **Screen Size** | The diagonal screen size measured in inches. |
# | **Screen Resolution** | The display resolution of the laptop. |
# | **CPU** | The processor type and speed, such as Intel Core i5 2.3GHz or AMD A9-Series 9420 3GHz. |
# | **RAM** | The amount of RAM installed, measured in GB. |
# | **Storage Type** | The type of storage device, such as SSD, HDD, or Flash Storage. |
# | **Storage Size** | The storage capacity of the laptop. |
# | **GPU** | The graphics processing unit and its specifications. |
# | **Operating System** | The operating system installed on the laptop, such as Windows, macOS, or Linux. |
# | **Weight** | The weight of the laptop measured in kilograms. |
# | **Price** | The selling price of the laptop and the target variable for the prediction model. |
#
# ---
#
# ## 🔍 Exploratory Data Analysis
#
# The exploratory analysis investigates the relationship between laptop specifications and prices.
#
# Some of the questions explored include:
#
# - Which laptop brands have the highest average prices?
# - Does RAM have a strong relationship with price?
# - How does storage capacity affect price?
# - Are SSD laptops more expensive than HDD laptops?
# - Does screen resolution influence price?
# - How does CPU performance relate to price?
# - Does GPU type have a significant effect on price?
# - Are there significant price differences between operating systems?
# - Which features have the strongest relationship with laptop price?
#
# Visualizations are used to identify trends, distributions, relationships, and potential outliers.
#
# ---
#
# ## 🤖 Machine Learning
#
# Since **Price** is a continuous numerical target, this project is treated as a **regression problem**.
#
# The project starts with a simple baseline model and then evaluates more advanced approaches.
#
# Potential models include:
#
# - Linear Regression
# - Ridge Regression
# - Lasso Regression
# - Random Forest Regressor
# - Gradient Boosting Regressor
#
# The models can then be compared to determine which approach provides the best predictive performance.
#
# ---
#
# ## 📏 Model Evaluation
#
# The regression models are evaluated using several metrics:
#
# ### Mean Absolute Error (MAE)
#
# Measures the average absolute difference between the actual and predicted prices.
#
# \[
# MAE = \frac{1}{n}\sum |y_i-\hat{y_i}|
# \]
#
# ### Root Mean Squared Error (RMSE)
#
# Penalizes larger prediction errors more strongly than MAE.
#
# \[
# RMSE = \sqrt{\frac{1}{n}\sum(y_i-\hat{y_i})^2}
# \]
#
# ### R² Score
#
# Measures how much of the variation in laptop prices is explained by the model.
#
# \[
# R^2 = 1-\frac{SS_{res}}{SS_{tot}}
# \]
#
# The final model will be evaluated using the test dataset to estimate its performance on previously unseen laptop specifications.
#
# ---
#
# ## 🛠️ Technologies & Libraries
#
# The project is developed using Python and the following libraries:
#
# - **Python**
# - **Pandas** — Data manipulation and cleaning
# - **NumPy** — Numerical computing
# - **Matplotlib** — Data visualization
# - **Seaborn** — Statistical visualization
# - **Scikit-learn** — Machine learning and preprocessing
# - **Jupyter Notebook** — Development and analysis environment
#
# ---
#
# ## 🔄 Project Workflow
#
# ```text
# Raw Dataset
#      ↓
# Data Inspection
#      ↓
# Data Cleaning
#      ↓
# Handling Missing Values
#      ↓
# Handling Inconsistent Data
#      ↓
# Feature Engineering
#      ↓
# Exploratory Data Analysis
#      ↓
# Encoding Categorical Features
#      ↓
# Train/Test Split
#      ↓
# Feature Scaling
#      ↓
# Model Training
#      ↓
# Cross-Validation & Hyperparameter Tuning
#      ↓
# Model Evaluation
#      ↓
# Final Laptop Price Prediction

# %% [markdown]
# # First, we import the necessary libreries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('laptopData.csv')
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %% [markdown]
# ### Let's check if any null value exist

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
# The unnamed column is a kind of index so we drop it, we do not need it

df = df.drop('Unnamed: 0', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 112.1+ KB

# %%
df.sample(4)
# Out:
#         Company            TypeName Inches  \
# 1299     Lenovo  2 in 1 Convertible   13.3
# 780        Dell              Gaming   17.3
# 70    Microsoft           Ultrabook   13.5
# 1290       Dell            Notebook   15.6
#
#                                 ScreenResolution                          Cpu  \
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800   Intel Core i7 6500U 2.5GHz
# 780                  IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
# 70                         Touchscreen 2256x1504   Intel Core i5 7200U 2.5GHz
# 1290                                    1366x768   Intel Core i3 7100U 2.4GHz
#
#        Ram              Memory                       Gpu         OpSys  \
# 1299  16GB           512GB SSD     Intel HD Graphics 520    Windows 10
# 780   32GB  1TB SSD +  1TB HDD  Nvidia GeForce GTX 1070M    Windows 10
# 70     4GB           128GB SSD     Intel HD Graphics 620  Windows 10 S
# ...

# %% [markdown]
# ### We seperate the categorical and numerical columns

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
# dtypes: object(10)
# memory usage: 101.9+ KB

# %%
df.select_dtypes(exclude='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1273 non-null   float64
# dtypes: float64(1)
# memory usage: 10.3 KB

# %% [markdown]
# __________________________________________________________________
# ##### As we see, the only numerical data is the target or the price

# %% [markdown]
# ````
# The first step is to look over the data and
# find out what we have and what is missed or not correct

# %%
df.describe()
# Out:
#                Price
# count    1273.000000
# mean    59955.814073
# std     37332.251005
# min      9270.720000
# 25%     31914.720000
# 50%     52161.120000
# 75%     79333.387200
# max    324954.720000

# %%
# It is important to copy the dataset and work on it, in case the original data is needed
tem_df = df.copy()

# %%
tem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   object
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Weight            1273 non-null   object
#  10  Price             1273 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 112.1+ KB

# %%
tem_df.isnull().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %% [markdown]
# ```
# We have 30 rows with null values that needs to be removed
# # Completeness issue

# %%
tem_df.duplicated().sum()
# Out:
# 58

# %% [markdown]
# ```
# The duplicated should be removed too
# # Duplicated issue

# %%
tem_df['Company'].value_counts()
# Out:
# Company
# Lenovo       290
# Dell         287
# HP           266
# Asus         156
# Acer         103
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %% [markdown]
# ```
# Here the Vero belongs to Acer company
# # Consistency issue

# %%
tem_df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              710
# Gaming                203
# Ultrabook             191
# 2 in 1 Convertible    116
# Workstation            29
# Netbook                24
# Name: count, dtype: int64

# %%
tem_df['Inches'].value_counts()
# Out:
# Inches
# 15.6    640
# 14      192
# 17.3    162
# 13.3    161
# 12.5     38
# 11.6     31
# 12        6
# 13.9      6
# 13.5      5
# 12.3      5
# 15.4      4
# 15        4
# 35.6      3
# 10.1      3
# 24        2
# 13        2
# 18.4      1
# 27.3      1
# 33.5      1
# ?         1
# 31.6      1
# 17        1
# 14.1      1
# 11.3      1
# 25.6      1
# Name: count, dtype: int64

# %% [markdown]
# ```
# We have a ? mark in our data and many unrealistic screen size such as 33.5 Inches for a laptop. The normal range for
# big screen laptop is between 18 to 18.5
# # Validity issue

# %%
tem_df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                495
# 1366x768                                         274
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         52
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  14
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160                9
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# Touchscreen 2560x1440                              6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %% [markdown]
# ```
# Here we have alot of info in one column and the data is abit messy
# # Structural and Consistency issue

# %%
tem_df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     128
# Intel Core i7 8550U 1.8GHz      72
# Intel Core i5 8250U 1.6GHz      68
#                               ...
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i7 2.2GHz             1
# AMD A6-Series 7310 2GHz          1
# Intel Atom Z8350 1.92GHz         1
# AMD E-Series 9000e 1.5GHz        1
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# ```
# # Structural and Consistency issue

# %%
tem_df['Ram'].value_counts()
# Out:
# Ram
# 8GB     601
# 4GB     367
# 16GB    194
# 6GB      40
# 12GB     25
# 2GB      22
# 32GB     17
# 64GB      3
# 24GB      3
# 1GB       1
# Name: count, dtype: int64

# %% [markdown]
# ```
# we have diferent units here
# # Consistency issue

# %%
tem_df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        401
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                14
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          4
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  500GB HDD             2
# ...

# %% [markdown]
# ```
# # Structural and Consistency issue

# %%
tem_df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      271
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      66
# Nvidia GeForce GTX 1050     64
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %% [markdown]
# ```
# # Structural and Consistency issue

# %%
tem_df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %% [markdown]
# ```
# # Structural and Consistency issue

# %%
tem_df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     111
# 2.1kg      57
# 2.4kg      43
# 2.3kg      41
# 2.5kg      37
#          ...
# 1.41kg      1
# 3.6kg       1
# 4.7kg       1
# 4.33kg      1
# 4.0kg       1
# Name: count, Length: 189, dtype: int64

# %% [markdown]
# ```
# Consistency

# %%
tem_df['Price'].describe()
# Out:
# count      1273.000000
# mean      59955.814073
# std       37332.251005
# min        9270.720000
# 25%       31914.720000
# 50%       52161.120000
# 75%       79333.387200
# max      324954.720000
# Name: Price, dtype: float64

# %% [markdown]
# # Completeness → Structural → Validity → Accuracy → Consistency

# %% [markdown]
# ```
# Let's fix the missing values and uplicateds

# %%
tem_df.isna().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
tem_df.duplicated().sum()
# Out:
# 58

# %%
# Our data shape Before droping nan values and duplicateds
tem_df.shape
# Out:
# (1303, 11)

# %%
tem_df = tem_df.dropna().reset_index(drop=True)

# %%
tem_df.shape
# Out:
# (1273, 11)

# %%
tem_df.drop_duplicates(inplace=True)

# %%
tem_df.shape
# Out:
# (1244, 11)

# %%
tem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1244 entries, 0 to 1243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1244 non-null   object
#  1   TypeName          1244 non-null   object
#  2   Inches            1244 non-null   object
#  3   ScreenResolution  1244 non-null   object
#  4   Cpu               1244 non-null   object
#  5   Ram               1244 non-null   object
#  6   Memory            1244 non-null   object
#  7   Gpu               1244 non-null   object
#  8   OpSys             1244 non-null   object
#  9   Weight            1244 non-null   object
#  10  Price             1244 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 116.6+ KB

# %% [markdown]
# ```
# Welldone we did solve the completeness issue

# %% [markdown]
# ```
# Let's go through the structural issue

# %%
tem_df['Company'] = tem_df['Company'].replace('Vero', 'Acer')

# %%
tem_df['Company'] = tem_df['Company'].str.strip()

# %%
tem_df['Company'].value_counts()
# Out:
# Company
# Lenovo       282
# Dell         281
# HP           260
# Asus         149
# Acer         105
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Chuwi          3
# Google         3
# LG             3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %% [markdown]
# ```
# We replaced Vero by Acer so the values are accutrate now.

# %%
tem_df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              689
# Gaming                203
# Ultrabook             189
# 2 in 1 Convertible    112
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
tem_df['TypeName'] = tem_df['TypeName'].replace('Netbook','Notebook')

# %%
tem_df['TypeName'] = tem_df['TypeName'].str.strip()

# %%
tem_df['TypeName'].describe()
# Out:
# count         1244
# unique           5
# top       Notebook
# freq           711
# Name: TypeName, dtype: object

# %%
tem_df['Inches'].value_counts()
# Out:
# Inches
# 15.6    621
# 14      188
# 17.3    162
# 13.3    157
# 12.5     38
# 11.6     29
# 12        6
# 13.9      6
# 13.5      5
# 12.3      5
# 15.4      4
# 15        4
# 35.6      3
# 10.1      3
# 24        2
# 13        2
# 18.4      1
# 27.3      1
# 33.5      1
# ?         1
# 31.6      1
# 17        1
# 14.1      1
# 11.3      1
# 25.6      1
# Name: count, dtype: int64

# %%
tem_df[tem_df['Inches'].isin(['25.6','31.6','35.6','27.3','33.5','24','?'])]
# Out:
#        Company            TypeName Inches             ScreenResolution  \
# 391     Lenovo            Notebook   25.6  IPS Panel Full HD 1920x1080
# 397     Lenovo            Notebook   35.6            Full HD 1920x1080
# 412       Asus            Notebook   35.6            Full HD 1920x1080
# 413       Dell              Gaming   27.3          IPS Panel 2560x1440
# 427     Lenovo           Ultrabook     24                    2560x1440
# 447  Microsoft           Ultrabook   33.5        Touchscreen 2256x1504
# 465       Dell         Workstation      ?            Full HD 1920x1080
# 513     Lenovo            Notebook     24            Full HD 1920x1080
# 579       Dell  2 in 1 Convertible   31.6         Touchscreen 1366x768
# 656     Lenovo            Notebook   35.6                     1366x768
#
#                              Cpu   Ram                Memory  \
# 391   Intel Core i5 8250U 1.6GHz   8GB  256GB SSD +  1TB HDD
# 397     Intel Core i3 6006U 2GHz   4GB             500GB HDD
# ...

# %% [markdown]
# ```
# Here the big numbers might be in cm not Inches

# %%
tem_df[(tem_df['Company']=='Dell') & (tem_df['TypeName'] == 'Workstation')]
# Out:
#     Company     TypeName Inches                     ScreenResolution  \
# 197    Dell  Workstation   15.6                4K Ultra HD 3840x2160
# 288    Dell  Workstation   17.3                    Full HD 1920x1080
# 376    Dell  Workstation   15.6                    Full HD 1920x1080
# 377    Dell  Workstation   15.6          IPS Panel Full HD 1920x1080
# 387    Dell  Workstation   15.6  4K Ultra HD / Touchscreen 3840x2160
# 436    Dell  Workstation   15.6                    Full HD 1920x1080
# 440    Dell  Workstation   15.6          IPS Panel Full HD 1920x1080
# 465    Dell  Workstation      ?                    Full HD 1920x1080
# 474    Dell  Workstation   15.6          IPS Panel Full HD 1920x1080
# 586    Dell  Workstation   15.6      Full HD / Touchscreen 1920x1080
# 847    Dell  Workstation   15.6                    Full HD 1920x1080
#
#                              Cpu   Ram                         Memory  \
# ...

# %%
cm = [25.6,31.6,35.6,27.3,33.5,24]
Inches = []

for num in cm:
    new_num = num * 0.393701
    Inches.append(new_num)

print(Inches)
# Out:
# [10.078745600000001, 12.440951600000002, 14.015755600000002, 10.748037300000002, 13.1889835, 9.448824]

# %%
tem_df['Inches'] = tem_df['Inches'].replace({
    '?': '15.6',
    '25.6': '10',
    '31.6': '12.4',
    '35.6': '14',
    '27.3': '10.7',
    '33.5': '13.1',
    '24': '9.4'
})

# %%
tem_df['Inches'].unique()
# Out:
# array(['13.3', '15.6', '15.4', '14', '12', '17.3', '13.5', '12.5', '13',
#        '18.4', '13.9', '11.6', '10', '12.3', '10.7', '9.4', '13.1',
#        '12.4', '17', '15', '14.1', '11.3', '10.1'], dtype=object)

# %%
tem_df['ScreenResolution'].unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', '1600x900',
#        'IPS Panel 4K Ultra HD 3840x2160', '4K Ultra HD 3840x2160',
#        'Touchscreen 1366x768', 'Touchscreen 2560x1440',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
#        '2560x1440', 'IPS Panel Quad HD+ 2560x1440',
# ...

# %% [markdown]
# ```
# Wer have Structural issue here

# %%
tem_df['ScreenResolution'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1244 entries, 0 to 1243
# Series name: ScreenResolution
# Non-Null Count  Dtype
# --------------  -----
# 1244 non-null   object
# dtypes: object(1)
# memory usage: 19.4+ KB

# %%
# We make a pattern and apply it to our messy data

pattern = r'\b\d{3,4}x\d{3,4}\b'

# we find the resolution from each messy value
tem_df['screen_resolution'] = tem_df['ScreenResolution'].str.findall(pattern).str.get(0)

# %%
tem_df['screen_resolution'].unique()
# Out:
# array(['2560x1600', '1440x900', '1920x1080', '2880x1800', '1366x768',
#        '2304x1440', '3200x1800', '2256x1504', '3840x2160', '2160x1440',
#        '1600x900', '2560x1440', '2736x1824', '2400x1600', '1920x1200'],
#       dtype=object)

# %%
# Here we define a function to get make the display type and add it to our dataset

def get_display_type(resolution):
    width, height = map(int, resolution.split('x'))

    if width >= 3840 and height >= 2160:
        return '4K'
    elif width >= 2560 and height >= 1440:
        return 'Quad HD'
    elif width >= 1920 and height >= 1080:
        return 'Full HD'
    elif width >= 1280 and height >= 720:
        return 'HD'
    else:
        return 'Other'

tem_df['display_type'] = tem_df['screen_resolution'].apply(get_display_type)

# %%
tem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1244 entries, 0 to 1243
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1244 non-null   object
#  1   TypeName           1244 non-null   object
#  2   Inches             1244 non-null   object
#  3   ScreenResolution   1244 non-null   object
#  4   Cpu                1244 non-null   object
#  5   Ram                1244 non-null   object
#  6   Memory             1244 non-null   object
#  7   Gpu                1244 non-null   object
#  8   OpSys              1244 non-null   object
#  9   Weight             1244 non-null   object
#  10  Price              1244 non-null   float64
#  11  screen_resolution  1244 non-null   object
#  12  display_type       1244 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 136.1+ KB

# %%
tem_df['display_type'].value_counts()
# Out:
# display_type
# Full HD    836
# HD         309
# Quad HD     57
# 4K          42
# Name: count, dtype: int64

# %% [markdown]
# ````
# Now we go through the cpu and get the important data from each messy value

# %%
tem_df['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Core i5 7300HQ 2.5GHz',
#        'AMD E-Series E2-9000e 1.5GHz', 'Intel Core i5 1.6GHz',
#        'Intel Core i7 8650U 1.9GHz', 'Intel Atom x5-Z8300 1.44GHz',
#        'AMD E-Series E2-6110 1.5GHz', 'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
# We need to get the brand, speed and type of each Cpu.

pattern = r'\b\d+(?:\.\d+)?(?:GHz|Hz)\b'  # get any value with GHZ or HZ

tem_df['processor_speed'] = tem_df['Cpu'].str.findall(pattern).str.get(0).str.split('G').str.get(0)

# %%
tem_df['processor_speed'].unique()
# Out:
# array(['2.3', '1.8', '2.5', '2.7', '3.1', '3', '2.2', '1.6', '2', '2.8',
#        '1.2', '2.9', '2.4', '1.5', '1.9', '1.44', '1.1', '2.0', '1.3',
#        '2.6', '3.6', '1.60', '3.2', '1.0', '2.1', '0.9', '1.92', '2.50',
#        '2.70'], dtype=object)

# %%
# We extract the brand

tem_df['processor_brand'] = tem_df['Cpu'].str.split(' ').str.get(0)
tem_df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'Samsung'], dtype=object)

# %%
# then we extract the type of processor

pattern = r'^[A-Za-z]+\s+(.+?)\s+\d+(?:\.\d+)?GHz'

tem_df['processor_type'] = tem_df['Cpu'].str.extract(pattern, expand=False)

# %%
tem_df['processor_type'].isnull().any()
# Out:
# False

# %%
tem_df['processor_type'].unique()
# Out:
# array(['Core i5', 'Core i5 7200U', 'Core i7', 'A9-Series 9420',
#        'Core i7 8550U', 'Core i5 8250U', 'Core i3 6006U', 'Core M m3',
#        'Core i7 7500U', 'Core i3 7100U', 'Core i5 7300HQ',
#        'E-Series E2-9000e', 'Core i7 8650U', 'Atom x5-Z8300',
#        'E-Series E2-6110', 'A6-Series 9220', 'Celeron Dual Core N3350',
#        'Core i3 7130U', 'Core i7 7700HQ', 'Ryzen 1700',
#        'Pentium Quad Core N4200', 'Celeron Dual Core N3060', 'FX 9830P',
#        'Core i7 7560U', 'E-Series 6110', 'Core i5 6200U', 'Core M 6Y75',
#        'Core i5 7500U', 'Core i7 6920HQ', 'Core i5 7Y54',
#        'Core i7 7820HK', 'Xeon E3-1505M V6', 'Core i7 6500U',
#        'E-Series 9000e', 'A10-Series A10-9620P', 'A6-Series A6-9220',
#        'Core i7 6600U', 'Celeron Dual Core 3205U', 'Core i7 7820HQ',
#        'A10-Series 9600P', 'Core i7 7600U', 'A8-Series 7410',
#        'Celeron Dual Core 3855U', 'Pentium Quad Core N3710',
# ...

# %%
tem_df.head()
# Out:
#   Company   TypeName Inches                    ScreenResolution  \
# 0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook   13.3                            1440x900
# 2      HP   Notebook   15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price screen_resolution  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832         2560x1600
# ...

# %% [markdown]
# ```
# Solving memory issue

# %%
tem_df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '?', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
tem_df[tem_df['Memory']=='?']
# Out:
#     Company  TypeName Inches   ScreenResolution                         Cpu  \
# 749    Dell  Notebook   15.6  Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
#
#       Ram Memory                 Gpu       OpSys Weight       Price  \
# 749  16GB      ?  AMD Radeon R7 M445  Windows 10  2.3kg  62938.0656
#
#     screen_resolution display_type processor_speed processor_brand  \
# 749         1920x1080      Full HD             2.7           Intel
#
#     processor_type
# 749  Core i7 7500U

# %%
tem_df[(tem_df['Company']=='Dell') & (tem_df['TypeName']=='Notebook') & (tem_df['Inches']=='15.6')
& (tem_df['display_type']=='Full HD') & ((tem_df['Ram']=='16GB'))]
# Out:
#      Company  TypeName Inches                 ScreenResolution  \
# 174     Dell  Notebook   15.6                Full HD 1920x1080
# 218     Dell  Notebook   15.6  Full HD / Touchscreen 1920x1080
# 227     Dell  Notebook   15.6                Full HD 1920x1080
# 475     Dell  Notebook   15.6                Full HD 1920x1080
# 501     Dell  Notebook   15.6                Full HD 1920x1080
# 570     Dell  Notebook   15.6                Full HD 1920x1080
# 641     Dell  Notebook   15.6                Full HD 1920x1080
# 696     Dell  Notebook   15.6                Full HD 1920x1080
# 749     Dell  Notebook   15.6                Full HD 1920x1080
# 1035    Dell  Notebook   15.6                Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 174    Intel Core i7 8550U 1.8GHz  16GB  256GB SSD +  2TB HDD
# 218    Intel Core i7 7500U 2.7GHz  16GB               1TB HDD
# 227    Intel Core i7 7500U 2.7GHz  16GB             256GB SSD
# ...

# %%
# we can put the memory 2 TB HDD cause it is very similar to row No 1035
tem_df['Memory'] = tem_df['Memory'].replace('?', '2TB HDD')

# %%
tem_df['Memory'] = tem_df['Memory'].replace('1TB HDD +  1TB HDD', '2TB HDD')

# %%
tem_df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '32GB HDD',
#        '1TB SSD +  1TB HDD', '512GB Flash Storage', '128GB HDD',
#        '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
tp = tem_df['Memory'].str.split(' ').str.get(0)
tp.unique()
# Out:
# array(['128GB', '256GB', '512GB', '500GB', '1TB', '64GB', '32GB', '2TB',
#        '1.0TB', '16GB', '180GB', '240GB', '8GB', '508GB'], dtype=object)

# %%
tem_df['Memory'] = (
    tem_df['Memory']
    .str.replace('1.0TB', '1000GB', regex=False)  # regex = False find exactly the same char
    .str.replace('1TB', '1000GB', regex=False)
    .str.replace('2TB', '2000GB', regex=False)
)

# %%
tem_df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1000GB HDD',
#        '128GB SSD +  1000GB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage',
#        '256GB SSD +  1000GB HDD', '256GB SSD +  2000GB HDD', '32GB SSD',
#        '2000GB HDD', '64GB SSD', '1000GB Hybrid',
#        '512GB SSD +  1000GB HDD', '1000GB SSD', '256GB SSD +  500GB HDD',
#        '128GB SSD +  2000GB HDD', '512GB SSD +  512GB SSD', '16GB SSD',
#        '16GB Flash Storage', '512GB SSD +  256GB SSD',
#        '512GB SSD +  2000GB HDD', '64GB Flash Storage +  1000GB HDD',
#        '180GB SSD', '32GB HDD', '1000GB SSD +  1000GB HDD',
#        '512GB Flash Storage', '128GB HDD', '240GB SSD', '8GB SSD',
#        '508GB Hybrid', '512GB SSD +  1000GB Hybrid',
#        '256GB SSD +  1000GB Hybrid'], dtype=object)

# %% [markdown]
# ```
# tem_df['ssd_storage'] = ?
# tew_df['hdd_storage'] = ?
# tem_df['flash_storage'] = ?

# %%
tem_df['ssd_storage'] = tem_df['Memory'].str.extract(r'(\d+(?:\.\d+)?)GB SSD', expand=False)
tem_df['hdd_storage'] = tem_df['Memory'].str.extract(r'(\d+(?:\.\d+)?)GB HDD', expand=False)
tem_df['flash_storage'] = tem_df['Memory'].str.extract(r'(\d+(?:\.\d+)?)GB Flash Storage', expand=False)

# %%
storage_columns = [
    'ssd_storage',
    'hdd_storage',
    'flash_storage'
]

# convert to numeric
tem_df[storage_columns] = (
    tem_df[storage_columns].apply(pd.to_numeric).fillna(0)
)

# %%
tem_df.sample(4)
# Out:
#      Company   TypeName Inches                  ScreenResolution  \
# 1029      HP   Notebook   15.6                          1366x768
# 872      MSI     Gaming   17.3   IPS Panel 4K Ultra HD 3840x2160
# 838   Lenovo   Notebook   15.6       IPS Panel Full HD 1920x1080
# 108     Dell  Ultrabook   13.3  Quad HD+ / Touchscreen 3200x1800
#
#                               Cpu   Ram                   Memory  \
# 1029   Intel Core i5 7200U 2.5GHz   4GB                500GB HDD
# 872   Intel Core i7 6700HQ 2.6GHz  16GB  512GB SSD +  2000GB HDD
# 838    Intel Core i5 7200U 2.5GHz   8GB               1000GB HDD
# 108    Intel Core i7 7560U 2.4GHz   8GB                256GB SSD
#
#                                Gpu       OpSys  Weight        Price  \
# 1029         Intel HD Graphics 620       No OS  1.96kg   26586.7200
# 872        Nvidia GeForce GTX 1060  Windows 10  2.43kg  141138.7200
# 838          Intel HD Graphics 620  Windows 10   2.3kg   45323.1648
# ...

# %% [markdown]
# ```
# We extact the numerical char from Ram column

# %%
tem_df['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '64GB', '6GB', '32GB', '24GB',
#        '1GB'], dtype=object)

# %%
tem_df['ram'] = tem_df['Ram'].str.split('GB').str.get(0).astype(int)

# %%
tem_df.sample(5)
# Out:
#       Company            TypeName Inches             ScreenResolution  \
# 1167       HP            Notebook   15.6  IPS Panel Full HD 1920x1080
# 378    Lenovo  2 in 1 Convertible     14        Touchscreen 2560x1440
# 1154     Dell            Notebook   15.6            Full HD 1920x1080
# 850   Toshiba            Notebook   15.6  IPS Panel Full HD 1920x1080
# 741    Google           Ultrabook   12.3        Touchscreen 2400x1600
#
#                               Cpu   Ram                   Memory  \
# 1167  Intel Core i7 7700HQ 2.8GHz  12GB  128GB SSD +  1000GB HDD
# 378    Intel Core i7 7500U 2.7GHz  16GB                512GB SSD
# 1154   Intel Core i7 7500U 2.7GHz   8GB                256GB SSD
# 850    Intel Core i7 7500U 2.7GHz   8GB                256GB SSD
# 741     Intel Core i5 7Y57 1.2GHz   8GB                256GB SSD
#
#                           Gpu       OpSys  Weight        Price  \
# 1167  Nvidia GeForce GTX 1050  Windows 10  2.21kg   70702.5600
# ...

# %% [markdown]
# ```
# We calssify the operating system

# %%
tem_df['OpSys'].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux',
#        'Windows 10 S', 'Chrome OS', 'Windows 7', 'Android'], dtype=object)

# %%
tem_df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1022
# No OS             63
# Linux             57
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
conditions = [
    tem_df['OpSys'].str.contains('Windows', case=False, na=False), # case=False,Don’t care whether the letters are uppercase or lowercase
    tem_df['OpSys'].str.contains('Mac|macos', case=False, na=False),
    tem_df['OpSys'].str.contains('Linux', case=False, na=False),
    tem_df['OpSys'].str.contains('No OS', case=False, na=False),
    tem_df['OpSys'].str.contains('Chrome', case=False, na=False),
    tem_df['OpSys'].str.contains('Android', case=False, na=False)
]

choices = [
    'windows',
    'mac',
    'linux',
    'no',
    'chrome',
    'android' 
]

tem_df['OS'] = np.select(
    conditions,
    choices,
    default='Other'
)

# %%
tem_df.sample(4)
# Out:
#      Company  TypeName Inches                               ScreenResolution  \
# 74      Dell  Notebook   15.6                              Full HD 1920x1080
# 746     Dell    Gaming   15.6  IPS Panel Touchscreen / 4K Ultra HD 3840x2160
# 343  Toshiba  Notebook   15.6                    IPS Panel Full HD 1920x1080
# 631    Razer    Gaming     14                              Full HD 1920x1080
#
#                              Cpu   Ram                   Memory  \
# 74    Intel Core i7 8550U 1.8GHz   8GB  128GB SSD +  1000GB HDD
# 746  Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1000GB HDD
# 343   Intel Core i7 6500U 2.5GHz  16GB                512GB SSD
# 631  Intel Core i7 7700HQ 2.8GHz  16GB                256GB SSD
#
#                          Gpu       OpSys  Weight  ...  screen_resolution  \
# 74    Intel UHD Graphics 620  Windows 10  2.02kg  ...          1920x1080
# 746  Nvidia GeForce GTX 960M  Windows 10  2.72kg  ...          3840x2160
# ...

# %% [markdown]
# ```
# The last column is weight that needs to be validated

# %%
tem_df['Weight'].unique()
# Out:
# array(['1.37kg', '1.34kg', '1.86kg', '1.83kg', '2.1kg', '2.04kg', '1.3kg',
#        '1.6kg', '2.2kg', '0.92kg', '1.22kg', '2.5kg', '1.62kg', '1.91kg',
#        '2.3kg', '1.35kg', '1.88kg', '1.89kg', '1.65kg', '2.71kg', '1.2kg',
#        '1.44kg', '2.8kg', '2kg', '2.65kg', '2.77kg', '3.2kg', '1.49kg',
#        '2.4kg', '2.13kg', '2.43kg', '1.7kg', '1.4kg', '1.8kg', '1.9kg',
#        '3kg', '1.252kg', '2.7kg', '2.02kg', '1.63kg', '1.96kg', '1.21kg',
#        '2.45kg', '1.25kg', '1.5kg', '2.62kg', '1.38kg', '1.58kg',
#        '1.85kg', '1.23kg', '2.16kg', '2.36kg', '7.2kg', '2.05kg',
#        '1.32kg', '1.75kg', '0.97kg', '2.56kg', '1.48kg', '1.74kg',
#        '1.1kg', '1.56kg', '2.03kg', '1.05kg', '5.4kg', '4.4kg', '1.90kg',
#        '1.29kg', '2.0kg', '1.95kg', '2.06kg', '1.12kg', '3.49kg',
#        '3.35kg', '2.23kg', '?', '2.9kg', '4.42kg', '2.69kg', '2.37kg',
#        '4.7kg', '3.6kg', '2.08kg', '4.3kg', '1.68kg', '1.41kg', '4.14kg',
# ...

# %%
tem_df['weight'] = tem_df['Weight'].str.split('kg').str.get(0)

# %%
tem_df["weight"] = pd.to_numeric(tem_df["weight"], errors="coerce")

# %% [markdown]
# ```
# Normally a laptop can be up to 4 Kg

# %%
tem_df['weight'].dtype
# Out:
# dtype('float64')

# %%
tem_df[tem_df['weight'] > 4]
# Out:
#       Company            TypeName Inches  \
# 128      Acer            Notebook   15.6
# 167   Toshiba            Notebook   15.6
# 171       MSI              Gaming   18.4
# 216      Dell              Gaming   17.3
# 230      Asus              Gaming   17.3
# 232    Lenovo            Notebook   15.6
# 243      Asus              Gaming   17.3
# 250       MSI              Gaming   17.3
# 258      Asus  2 in 1 Convertible   13.3
# 293    Lenovo            Notebook   17.3
# 317      Acer            Notebook   15.6
# 413      Dell              Gaming   10.7
# 445      Dell            Notebook   17.3
# 482      Asus              Gaming   17.3
# 518      Dell              Gaming   17.3
# 540      Dell              Gaming   17.3
# 564    Lenovo              Gaming   17.3
# 565       MSI              Gaming   17.3
# 572       MSI              Gaming   17.3
# 574    Lenovo           Ultrabook     14
# 590       MSI              Gaming   17.3
# 614      Asus           Ultrabook     14
# ...

# %%
tem_df['inches'] = pd.to_numeric(tem_df['Inches'], errors='coerce')

# %%
sns.scatterplot(x=tem_df['inches'], y=tem_df['weight'] );

# %%
tem_df.corr(numeric_only=True)['weight']
# Out:
# Price            0.176362
# ssd_storage     -0.028213
# hdd_storage      0.403241
# flash_storage   -0.151143
# ram              0.286238
# weight           1.000000
# inches           0.658861
# Name: weight, dtype: float64

# %% [markdown]
# ```
# we compute the mean of each laptop from the size of screen

# %%
tem_df.groupby('inches')['weight'].mean()
# Out:
# inches
# 9.4     1.670000
# 10.0    2.100000
# 10.1    0.690000
# 10.7    4.420000
# 11.3    1.100000
# 11.6    1.301379
# 12.0    0.920000
# 12.3    1.170000
# 12.4    1.390000
# 12.5    1.293947
# 13.0    1.050000
# 13.1    1.250000
# 13.3    1.348462
# 13.5    1.251600
# 13.9    1.388333
# 14.0    1.680105
# 14.1    1.650000
# 15.0    1.547500
# 15.4    1.882500
# 15.6    2.225422
# 17.0    2.600000
# 17.3    3.192901
# 18.4    4.400000
# Name: weight, dtype: float64

# %% [markdown]
# #### Now we change the invalid values by valid ones in weight column

# %%
avg_weight = (tem_df['weight']
              .where(tem_df['weight'] <= 4)
              .groupby(tem_df['inches'])
             .transform('mean')) #transform() returns an average for every row, aligned with the original DataFrame

# %%
tem_df.loc[tem_df['weight'] > 4, 'weight'] = avg_weight

# %%
tem_df.sample(5)
# Out:
#      Company   TypeName Inches                           ScreenResolution  \
# 723  Toshiba   Notebook     14  IPS Panel Full HD / Touchscreen 1920x1080
# 386   Lenovo   Notebook     14                IPS Panel Full HD 1920x1080
# 192       HP   Notebook   17.3                          Full HD 1920x1080
# 887       LG  Ultrabook     14  IPS Panel Full HD / Touchscreen 1920x1080
# 304     Acer   Notebook   15.6                          Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 723  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
# 386  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
# 192  Intel Core i7 8550U 1.8GHz  8GB  256GB SSD  Nvidia GeForce 930MX
# 887  Intel Core i7 7500U 2.7GHz  8GB  512GB SSD  Intel HD Graphics 620
# 304   AMD A8-Series 7410 2.2GHz  8GB  256GB SSD          AMD Radeon R5
#
#           OpSys  Weight  ...  processor_speed processor_brand  processor_type  \
# ...

# %%
tem_df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price', 'screen_resolution',
#        'display_type', 'processor_speed', 'processor_brand', 'processor_type',
#        'ssd_storage', 'hdd_storage', 'flash_storage', 'ram', 'OS', 'weight',
#        'inches'],
#       dtype='object')

# %%
tem_df[tem_df['weight'].isna()]
# Out:
#     Company TypeName Inches     ScreenResolution                          Cpu  \
# 171     MSI   Gaming   18.4    Full HD 1920x1080  Intel Core i7 6920HQ 2.9GHz
# 413    Dell   Gaming   10.7  IPS Panel 2560x1440  Intel Core i7 7820HK 2.9GHz
#
#       Ram                   Memory                      Gpu       OpSys  \
# 171  32GB  512GB SSD +  1000GB HDD       Nvidia GTX 980 SLI  Windows 10
# 413  16GB  256GB SSD +  1000GB HDD  Nvidia GeForce GTX 1070  Windows 10
#
#      Weight  ...  processor_speed processor_brand  processor_type ssd_storage  \
# 171   4.4kg  ...              2.9           Intel  Core i7 6920HQ       512.0
# 413  4.42kg  ...              2.9           Intel  Core i7 7820HK       256.0
#
#     hdd_storage flash_storage  ram       OS  weight  inches
# 171      1000.0           0.0   32  windows     NaN    18.4
# 413      1000.0           0.0   16  windows     NaN    10.7
#
# [2 rows x 23 columns]

# %%
tem_df.loc[201, 'weight'] = 1.1

# %%
tem_df[tem_df['Weight'] == '4kg']
# Out:
#      Company TypeName Inches             ScreenResolution  \
# 1033    Asus   Gaming   17.3  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram      Memory                      Gpu  \
# 1033  Intel Core i7 6700HQ 2.6GHz  16GB  1000GB HDD  Nvidia GeForce GTX 965M
#
#       OpSys Weight  ...  processor_speed processor_brand  processor_type  \
# 1033  No OS    4kg  ...              2.6           Intel  Core i7 6700HQ
#
#      ssd_storage hdd_storage flash_storage  ram  OS  weight  inches
# 1033         0.0      1000.0           0.0   16  no     4.0    17.3
#
# [1 rows x 23 columns]

# %%
tem_df.loc[171, 'weight'] = 4

# %%
tem_df.loc[413, 'weight'] = 4

# %%
tem_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1244 entries, 0 to 1243
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1244 non-null   object
#  1   TypeName           1244 non-null   object
#  2   Inches             1244 non-null   object
#  3   ScreenResolution   1244 non-null   object
#  4   Cpu                1244 non-null   object
#  5   Ram                1244 non-null   object
#  6   Memory             1244 non-null   object
#  7   Gpu                1244 non-null   object
#  8   OpSys              1244 non-null   object
#  9   Weight             1244 non-null   object
#  10  Price              1244 non-null   float64
#  11  screen_resolution  1244 non-null   object
#  12  display_type       1244 non-null   object
#  13  processor_speed    1244 non-null   object
#  14  processor_brand    1244 non-null   object
#  15  processor_type     1244 non-null   object
# ...

# %%
clean_df = tem_df[['Company', 'TypeName', 'inches','weight','screen_resolution',
                     'display_type', 'processor_speed', 'processor_brand', 'processor_type',
                     'ssd_storage', 'hdd_storage', 'flash_storage', 'ram', 'OS','Price']]

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1244 entries, 0 to 1243
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1244 non-null   object
#  1   TypeName           1244 non-null   object
#  2   inches             1244 non-null   float64
#  3   weight             1244 non-null   float64
#  4   screen_resolution  1244 non-null   object
#  5   display_type       1244 non-null   object
#  6   processor_speed    1244 non-null   object
#  7   processor_brand    1244 non-null   object
#  8   processor_type     1244 non-null   object
#  9   ssd_storage        1244 non-null   float64
#  10  hdd_storage        1244 non-null   float64
#  11  flash_storage      1244 non-null   float64
#  12  ram                1244 non-null   int64
#  13  OS                 1244 non-null   object
#  14  Price              1244 non-null   float64
# dtypes: float64(6), int64(1), object(8)
# ...

# %%
clean_df.sample(5)
# Out:
#      Company            TypeName  inches  weight screen_resolution  \
# 183     Dell            Notebook    17.3    2.80         1920x1080
# 345   Lenovo            Notebook    15.6    2.20          1366x768
# 1213    Acer            Notebook    15.6    2.40          1366x768
# 825     Asus           Ultrabook    13.3    1.45         1920x1080
# 724   Lenovo  2 in 1 Convertible    14.0    1.70         1920x1080
#
#      display_type processor_speed processor_brand           processor_type  \
# 183       Full HD             1.8           Intel            Core i7 8550U
# 345            HD             1.1           Intel  Celeron Dual Core N3350
# 1213           HD             2.0           Intel            Core i3 6006U
# 825       Full HD             2.3           Intel            Core i5 6200U
# 724       Full HD             2.5           Intel            Core i5 7200U
#
#       ssd_storage  hdd_storage  flash_storage  ram       OS       Price
# ...

# %%
clean_df.columns = clean_df.columns.str.capitalize()

# %%
clean_df.sample(5)
# Out:
#      Company            Typename  Inches  Weight Screen_resolution  \
# 751  Toshiba            Notebook    14.0    1.75          1366x768
# 513   Lenovo            Notebook     9.4    2.02         1920x1080
# 585     Dell  2 in 1 Convertible    12.5    1.34         1920x1080
# 654   Lenovo            Notebook    15.6    1.90         1920x1080
# 523     Dell            Notebook    15.6    1.93         1920x1080
#
#     Display_type Processor_speed Processor_brand Processor_type  Ssd_storage  \
# 751           HD             2.3           Intel  Core i5 6200U        128.0
# 513      Full HD             2.3           Intel  Core i5 6200U        256.0
# 585      Full HD             2.5           Intel  Core i5 7200U        256.0
# 654      Full HD             2.5           Intel  Core i5 7200U        128.0
# 523      Full HD             2.8           Intel  Core i7 7600U        256.0
#
#      Hdd_storage  Flash_storage  Ram       Os      Price
# ...

# %%
clean_df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# # Well done
